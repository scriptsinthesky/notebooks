# %%
import nmap

print('----------------------------------------------------')
# Asynchronous usage of PortScannerAsync
nma = nmap.PortScannerAsync()
def callback_result(host, scan_result):
    print('------------------')
    print(host, scan_result)
    
nma.scan(hosts='192.168.0.1-254', arguments='-sP', callback=callback_result)
while nma.still_scanning():
    print("Waiting ...")
    nma.wait(2) # you can do whatever you want but I choose to wait after the end of the scan
# Out:
# ----------------------------------------------------
# Waiting ...
# Waiting ...
# Waiting ...
# Waiting ...
# Waiting ...
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.1 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.1', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.02', 'timestr': 'Sat Jul 30 23:32:43 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.1': {'hostnames': [{'name': 'router.asus.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.1'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.10 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.10', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:32:46 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.100 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.100', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:32:49 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.101 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.101', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:32:52 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.102 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.102', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:32:55 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.103 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.103', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:32:58 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.104 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.104', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:01 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.105 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.105', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:33:04 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.106 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.106', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:07 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.107 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.107', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:11 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.108 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.108', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:33:14 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.109 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.109', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:17 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.11 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.11', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:20 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.110 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.110', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:23 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.111 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.111', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:33:26 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.112 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.112', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:29 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.113 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.113', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:33:32 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.114 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.114', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:33:35 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.115 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.115', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:38 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.116 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.116', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:41 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.117 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.117', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:44 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.118 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.118', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:47 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.119 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.119', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:33:50 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.12 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.12', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:53 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.120 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.120', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:56 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.121 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.121', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:33:59 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.122 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.122', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:02 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.123 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.123', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:05 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.124 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.124', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:34:08 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.125 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.125', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:11 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.126 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.126', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:14 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.127 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.127', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:17 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.128 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.128', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:20 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.129 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.129', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:23 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.13 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.13', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.07', 'timestr': 'Sat Jul 30 23:34:23 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.13': {'hostnames': [{'name': 'pi8.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.13'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.130 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.130', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:34:26 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.131 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.131', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.01', 'timestr': 'Sat Jul 30 23:34:27 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.131': {'hostnames': [{'name': 'pi9.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.131'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.132 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.132', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:30 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.133 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.133', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:33 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.134 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.134', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:36 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.135 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.135', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:39 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.136 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.136', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:34:42 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.137 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.137', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:45 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.138 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.138', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:48 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.139 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.139', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:51 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.14 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.14', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.02', 'timestr': 'Sat Jul 30 23:34:51 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.14': {'hostnames': [{'name': 'pi12.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.14'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.140 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.140', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:34:54 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.141 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.141', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:34:57 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.142 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.142', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:00 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.143 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.143', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:03 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.144 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.144', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:06 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.145 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.145', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:35:09 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.146 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.146', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:12 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.147 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.147', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:35:15 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.148 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.148', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:18 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.149 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.149', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:21 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.15 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.15', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.02', 'timestr': 'Sat Jul 30 23:35:21 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.15': {'hostnames': [{'name': 'pi2.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.15'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.150 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.150', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:24 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.151 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.151', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:27 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.152 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.152', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:35:30 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.153 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.153', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:35:33 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.154 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.154', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.03', 'timestr': 'Sat Jul 30 23:35:33 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.154': {'hostnames': [{'name': 'pi11.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.154'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.155 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.155', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:35:37 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.156 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.156', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.02', 'timestr': 'Sat Jul 30 23:35:40 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.157 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.157', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.03', 'timestr': 'Sat Jul 30 23:35:43 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.158 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.158', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:46 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.159 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.159', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:49 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.16 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.16', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.22', 'timestr': 'Sat Jul 30 23:35:49 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.16': {'hostnames': [{'name': '', 'type': ''}], 'addresses': {'ipv4': '192.168.0.16'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.160 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.160', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:52 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.161 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.161', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:55 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.162 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.162', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:35:58 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.163 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.163', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:01 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.164 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.164', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:04 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.165 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.165', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.02', 'timestr': 'Sat Jul 30 23:36:04 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.165': {'hostnames': [{'name': 'kali.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.165'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.166 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.166', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:07 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.167 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.167', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:10 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.168 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.168', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:36:13 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.169 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.169', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:17 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.17 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.17', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.55', 'timestr': 'Sat Jul 30 23:36:17 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.17': {'hostnames': [{'name': 'pi3.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.17'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.170 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.170', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:20 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.171 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.171', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:23 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.172 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.172', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:36:26 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.173 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.173', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:36:29 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.174 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.174', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:32 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.175 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.175', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.15', 'timestr': 'Sat Jul 30 23:36:32 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.175': {'hostnames': [{'name': 'pi13.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.175'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.176 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.176', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:36:35 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.177 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.177', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:39 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.178 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.178', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:42 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.179 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.179', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:36:45 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.18 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.18', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.09', 'timestr': 'Sat Jul 30 23:36:45 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.18': {'hostnames': [{'name': 'pi4.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.18'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.180 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.180', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:48 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.181 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.181', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:51 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.182 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.182', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:36:54 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.183 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.183', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:36:57 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.184 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.184', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '5.15', 'timestr': 'Sat Jul 30 23:37:02 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.184': {'hostnames': [{'name': 'beast666.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.184'}, 'status': {'state': 'up', 'reason': 'syn-ack'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.185 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.185', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:37:05 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.186 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.186', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:37:08 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.187 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.187', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:11 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.188 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.188', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:14 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.189 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.189', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:17 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.19 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.19', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:20 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.190 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.190', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:23 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.191 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.191', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:37:26 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.192 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.192', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:37:29 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.193 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.193', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:37:32 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.194 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.194', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:37:36 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.195 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.195', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:39 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.196 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.196', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:42 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.197 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.197', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:45 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.198 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.198', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:48 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.199 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.199', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.34', 'timestr': 'Sat Jul 30 23:37:48 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.199': {'hostnames': [{'name': '', 'type': ''}], 'addresses': {'ipv4': '192.168.0.199'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.2 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.2', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:51 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.20 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.20', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:54 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.200 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.200', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:37:57 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.201 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.201', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:00 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.202 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.202', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:03 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.203 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.203', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:06 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.204 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.204', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:09 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.205 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.205', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:12 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.206 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.206', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:15 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.207 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.207', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:18 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.208 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.208', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:21 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.209 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.209', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:24 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.21 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.21', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:28 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.210 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.210', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:31 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.211 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.211', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:34 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.212 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.212', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:37 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.213 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.213', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:40 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.214 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.214', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:43 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.215 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.215', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:46 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.216 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.216', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:49 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.217 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.217', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:52 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.218 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.218', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:38:55 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.219 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.219', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:38:58 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.22 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.22', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:01 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.220 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.220', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:04 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.221 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.221', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:07 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.222 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.222', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:10 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.223 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.223', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:13 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.224 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.224', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:16 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.225 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.225', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:19 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.226 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.226', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:22 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.227 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.227', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:25 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.228 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.228', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:28 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.229 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.229', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:31 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.23 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.23', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:34 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.230 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.230', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:37 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.231 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.231', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:40 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.232 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.232', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:44 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.233 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.233', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:47 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.234 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.234', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:50 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.235 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.235', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:53 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.236 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.236', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:39:56 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.237 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.237', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:39:59 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.238 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.238', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:02 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.239 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.239', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:05 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.24 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.24', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:08 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.240 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.240', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:11 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.241 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.241', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:14 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.242 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.242', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:17 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.243 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.243', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:20 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.244 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.244', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:23 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.245 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.245', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:26 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.246 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.246', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:29 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.247 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.247', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:32 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.248 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.248', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:35 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.249 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.249', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:38 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.25 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.25', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:41 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.250 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.250', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:44 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.251 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.251', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:40:47 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.252 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.252', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:50 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.253 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.253', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:53 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.254 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.254', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:40:56 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# ...
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.48 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.48', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:42:09 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.49 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.49', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:12 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.5 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.5', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.30', 'timestr': 'Sat Jul 30 23:42:13 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.5': {'hostnames': [{'name': 'pi1.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.5'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.50 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.50', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:16 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.51 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.51', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:42:19 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.52 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.52', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:22 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.53 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.53', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:25 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.54 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.54', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:28 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.55 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.55', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:31 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.56 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.56', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:42:34 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.57 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.57', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:37 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.58 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.58', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:42:40 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.59 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.59', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:43 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.6 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.6', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:46 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.60 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.60', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:42:49 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.61 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.61', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.09', 'timestr': 'Sat Jul 30 23:42:49 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.61': {'hostnames': [{'name': 'cloudcommander.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.61'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.62 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.62', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:52 2016', 'downhosts': '1'}}, 'scan': {}}
# ------------------
# 192.168.0.63 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.63', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.02', 'timestr': 'Sat Jul 30 23:42:53 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.63': {'hostnames': [{'name': 'pi6.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.63'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.64 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.64', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:42:56 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.65 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.65', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:42:59 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.66 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.66', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:02 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.67 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.67', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:05 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.68 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.68', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:08 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.69 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.69', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:43:11 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.7 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.7', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '2.02', 'timestr': 'Sat Jul 30 23:43:13 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.7': {'hostnames': [{'name': 'tutulu.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.7'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.70 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.70', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:16 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.71 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.71', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:19 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.72 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.72', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '1', 'elapsed': '0.01', 'timestr': 'Sat Jul 30 23:43:19 2016', 'downhosts': '0'}}, 'scan': {'192.168.0.72': {'hostnames': [{'name': 'cicourse.qclocal.com', 'type': 'PTR'}], 'addresses': {'ipv4': '192.168.0.72'}, 'status': {'state': 'up', 'reason': 'conn-refused'}, 'vendor': {}}}}
# Waiting ...
# ------------------
# 192.168.0.73 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.73', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:43:22 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.74 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.74', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:25 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.75 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.75', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:28 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.76 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.76', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:31 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.77 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.77', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:34 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.78 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.78', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:43:37 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.79 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.79', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:40 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.8 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.8', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:43:43 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.80 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.80', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:46 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.81 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.81', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:49 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.82 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.82', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:52 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.83 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.83', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:43:55 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.84 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.84', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:43:58 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.85 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.85', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:44:01 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.86 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.86', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:05 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.87 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.87', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:08 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.88 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.88', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:11 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.89 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.89', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:14 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.9 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.9', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:44:17 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.90 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.90', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:20 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.91 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.91', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:44:23 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.92 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.92', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:26 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.93 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.93', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:29 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.94 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.94', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:32 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.95 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.95', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:44:35 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.96 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.96', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:38 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# ------------------
# 192.168.0.97 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.97', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:41 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.98 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.98', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.00', 'timestr': 'Sat Jul 30 23:44:44 2016', 'downhosts': '1'}}, 'scan': {}}
# Waiting ...
# Waiting ...
# ------------------
# 192.168.0.99 {'nmap': {'command_line': 'nmap -oX - -sP 192.168.0.99', 'scaninfo': {}, 'scanstats': {'totalhosts': '1', 'uphosts': '0', 'elapsed': '3.01', 'timestr': 'Sat Jul 30 23:44:47 2016', 'downhosts': '1'}}, 'scan': {}}
